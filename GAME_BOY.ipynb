# %%
#####################################################################################################
#                           This is the Borderlands - Text Game Edition.                            #
#    You will be narrated by Claptrap, a robot that claims to be the General of the Crimson Raiders.#
#   The story is inspired by the Borderlands game-series, where Claptrap has some small appearances.# 
#           You will be asked to select between different classes, also called Vault Hunters.       #
#                     In this game you will end up fighting a boss.                                 #
#              Your class and weapon decision will affect if you live or die.                       #
#           The game is a looter-shooter, you kill enemies and receive the loot they possess.       #
#                 This loot can be everything from shields to big bazookas.                         #
#               Here is the link to their webpage https://borderlands.com/en-US/                    #
#  Bugs: Boss-stage is probably not "bulletproof", and there should be a while-loop in the fail     #
#                  to check for inputs and make it run more smoothly.                               #
#####################################################################################################

import sys
from random import randint
import time
import pandas as pd

#################################################
#      Create class table and weapon table      #
#################################################

classes = ['Soldier', 'Siren', 'Hunter']
class_dmg = [1, 0.5, 0.1]
class_dict = {'class':classes, 'damage':class_dmg}
class_pd = pd.DataFrame(class_dict)

weapons = ['RPG', 'Machine Gun', 'Pistol', 'Bubble Gun']
weapon_dmg = [0.99, 0.97, 0.4, 0.01]
weapon_dict  = {'weapon':weapons, 'damage':weapon_dmg}
weapons_pd = pd.DataFrame(weapon_dict)

narrator = "Claptrap"


###############################################################################################
#                         Defining the start of the game                                      #
# Throughout most of the game you will find for-loops that print out strings that are pre-set.#
#     In game_start you will also be introduced to while-loops that controls for input.       # 
###############################################################################################


def game_start():
    
    global your_name
    global last_name
    
    
    string1 = f"Hello! You must be the new recruit. Welcome to Pandora, the land of murderers and thieves. My name is {narrator}, and I am the General of the Crimson Raiders!\n\n"
    
    for char in string1:
        sys.stdout.write(char)
        sys.stdout.flush()
        time.sleep(.01)
    
    time.sleep(0.2)
    
    string2 = "So, Recruit, what is your first name? \n\n"
    
    for char in string2:
        sys.stdout.write(char)
        sys.stdout.flush()
        time.sleep(.01)
    
    your_name = input("> ")
    
    while True:
        
        if your_name.isalpha():
            break
        else:
            er_your_name = "\nUsually names only contain letters. Please write your name with letters only."
            for char in er_your_name:
                sys.stdout.write(char)
                sys.stdout.flush()
                time.sleep(.01)
            
            your_name = input("\n< So let's try again, What is your name?\n >")
    
    time.sleep(0.2)
    
    string3 = f"Alright {your_name}. What is your last name? Just for... You know... Eh. Nevermind. \n\n"
    
    for char in string3:
        sys.stdout.write(char)
        sys.stdout.flush()
        time.sleep(.01)
    
    last_name = input("> ")
    
    while True:
        
        if last_name.isalpha():
            break
        else:
            er_last_name = "\nUsually last names only contain letters. Please write your last name with letters only."
            for char in er_last_name:
                sys.stdout.write(char)
                sys.stdout.flush()
                time.sleep(.01)
            
            last_name = input("\n< No funky business. What is your last name?\n >")
    
    time.sleep(0.2)

    
    string4 = f"""
Thank you very much, {your_name} {last_name}. I will preorder your tombstone juuuuuuuuuuuuuust in case, but don't worry... \n\n
yet. \n\n
Remember that every choice you make from this point on will determine your future... (if you will even have one.)\n
Before continuing our journey you need to pick your desired class."""
    
    for char in string4:
        sys.stdout.write(char)
        sys.stdout.flush()
        time.sleep(.01)
        
    time.sleep(0.2)
    
    input('< Press Enter to Continue >')
    
    choose_class()



#######################################################################################
#               Below you will find the code for choose_class.                        #
# It contains a non-infinite while loop, with the same for loops that I use for print.#
#      If you fail to do as commanded, you will end up in a fail definition.          #
#               This section also include nested statements.                          #
#######################################################################################

def choose_class():
   
    global your_class
    
    dont_waste_time = 3
    
    while dont_waste_time > 0:
    
        string5 = f"""\nSo, Recruit {last_name}, what class do you choose?
        1. The ULTIMATE Soldier.
        2. The Magical Siren.
        3. The UnderDOG Hunter.\n"""
        
        for char in string5:
            sys.stdout.write(char)
            sys.stdout.flush()
            time.sleep(.01)
        
        time.sleep(0.2)
    
        your_class_choice = input('Choose your class: ')
        your_class_choice = your_class_choice.lower()
    
        if "1" in your_class_choice or "ultimate" in your_class_choice or "soldier" in your_class_choice:
           
            your_class = class_pd.iloc[0,0]
            
            string6 = f"\nGood for you. You have upgraded to Apprentice {your_class} {last_name}.\n"
            
            for char in string6:
                sys.stdout.write(char)
                sys.stdout.flush()
                time.sleep(.01)
            
            time.sleep(0.2)
            
            input('< Press Enter to Continue your journey! >')
            
            choose_weapon()
            break 
        
        elif "2" in your_class_choice or "magical" in your_class_choice or "siren" in your_class_choice:
            
            your_class = class_pd.iloc[1,0]
            
            string7 = f"\nCool. You have upgraded to Apprentice {your_class} {last_name}. \n"
            
            for char in string7:
                sys.stdout.write(char)
                sys.stdout.flush()
                time.sleep(.01)
                
            time.sleep(0.2)
            
            input('< Press Enter to Continue your journey! >')
            
            choose_weapon()
            break
        
        elif "3" in your_class_choice or "underdog" in your_class_choice or "hunter" in your_class_choice:
            
            your_class = class_pd.iloc[2,0]
            
            string8 = f"\nInteresting choice... You have upgraded to Apprentice {your_class} {last_name}. \n"
            
            for char in string8:
                sys.stdout.write(char)
                sys.stdout.flush()
                time.sleep(.01)
                
            time.sleep(0.2)
            
            input('< Press Enter to Continue your journey! >')
            
            choose_weapon()
            break
        
        else:
            
            string9 = "Don't waste my time, Recruit. Please choose a given class."
            
            for char in string9:
                sys.stdout.write(char)
                sys.stdout.flush()
                time.sleep(.01)
                
            time.sleep(0.2)
            
            dont_waste_time -=  1
        
    fail_1()  
        

        
        
##############################################################################################
# In this section you will find a while statement that keeps going until you pick your weapon#
#                           This includes the for loops for printing                         #
##############################################################################################
        
        
def choose_weapon(): 
    
    global your_weapon
    
    string10 = "\nNow follow me to this super-secret weaponlocker.\n"
    
    for char in string10:
        sys.stdout.write(char)
        sys.stdout.flush()
        time.sleep(.01)
                
    time.sleep(0.2)
    
    
    input(f'< Press Enter to follow {narrator}. >\n')
    
    string11 = "\nGreat job taking these commands. You will be a nice guarddog in the future.\n"
    
    for char in string11:
        sys.stdout.write(char)
        sys.stdout.flush()
        time.sleep(.01)
                
    time.sleep(0.2)
    
    while True: 
        
        string12 = f"""\nNow select one of these limb-tearing weapons:
    1. RPG (Rocket-Propelled Grenade gun)
    2. Machine Gun
    3. Pistol
    4. Bubble Gun"""
    
        for char in string12:
            sys.stdout.write(char)
            sys.stdout.flush()
            time.sleep(.01)
                
        time.sleep(0.2)
    
        your_weapon_choice = input('< Select between the gun, followed by hitting ENTER >')
        your_weapon_choice = your_weapon_choice.lower()
    
        if "1" in your_weapon_choice or "rpg" in your_weapon_choice:
            your_weapon = weapons_pd.iloc[0,0]
            string13 = f"\nYou think you are you able to handle all of this firepower, huh? We will see. Here you have the {your_weapon}."
            
            for char in string13:
                sys.stdout.write(char)
                sys.stdout.flush()
                time.sleep(.01)
            
            time.sleep(0.2)
            
            string14 = "\nNow you have your weapon, let us see how it works against Olav the Destroyer.\n"
            
            for char in string14:
                sys.stdout.write(char)
                sys.stdout.flush()
                time.sleep(.01)
            
            time.sleep(0.2)
            
            input(" < Press ENTER to have a shot at Olav. > ")
            
            boss_fight()
            break
        
        
        elif "2" in your_weapon_choice or "machine gun" in your_weapon_choice or "machine" in your_weapon_choice:
            your_weapon = weapons_pd.iloc[1,0]
            
            string15 = f"\nGreat choice! Make sure to practise your aim with this one, it has a high fire rate. Here you have the {your_weapon}."
            
            for char in string15:
                sys.stdout.write(char)
                sys.stdout.flush()
                time.sleep(.01)
            
            time.sleep(0.2)
            
            string16 = "\nNow you have your weapon, let us see how it works against Olav the Destroyer.\n"
            
            for char in string16:
                sys.stdout.write(char)
                sys.stdout.flush()
                time.sleep(.01)
            
            time.sleep(0.2)
            
            input(' < Press ENTER to have a shot at Olav. > ')
            
            boss_fight()
            break
        
        elif "3" in your_weapon_choice or "pistol" in your_weapon_choice:
            your_weapon = weapons_pd.iloc[2,0]
            
            string17 = f"I will not question your decision, but the pistol? For real? Alright, catch it. *{narrator} throws you the {your_weapon}.*"
            
            for char in string17:
                sys.stdout.write(char)
                sys.stdout.flush()
                time.sleep(.01)
            
            time.sleep(0.2)
            
            string18 = "\nNow you have your weapon, let us see how it works against Olav the Destroyer.\n"
            
            for char in string18:
                sys.stdout.write(char)
                sys.stdout.flush()
                time.sleep(.01)
            
            time.sleep(0.2)
            
            input(" < Press ENTER to have a shot at Olav. > ")
            
            boss_fight()
            break
        
        elif "4" in your_weapon_choice or "bubble" in your_weapon_choice or "bubble gun" in your_weapon_choice:
            your_weapon = weapons_pd.iloc[3,0]
            
            string19 = f"\nI am not sure this life is for a coward like you, but whatever. Here you have the {your_weapon}.\n"
            
            for char in string19:
                sys.stdout.write(char)
                sys.stdout.flush()
                time.sleep(.01)
            
            time.sleep(0.2)
            
            string20 = "\nNow you have your weapon, let us see how it works against Olav the Destroyer."
            
            for char in string20:
                sys.stdout.write(char)
                sys.stdout.flush()
                time.sleep(.01)
            
            time.sleep(0.2)
            
            input( "< Press ENTER to have a shot at Olav. > ")
            
            boss_fight()
            break
        
        else:
            string21 = "You need to start paying attention to the instructions. Pick again."
            
            for char in string21:
                sys.stdout.write(char)
                sys.stdout.flush()
                time.sleep(.01)
            
            time.sleep(0.2)
        
        
    
###########################################################################################
#                                    The Infamous Boss-fight                              #
#                            You will not find the for loops used for printing here.      #
#     You will find a while loop that is based upon boss life and your own life.          #
#                           You will find conditional statements                          #
###########################################################################################    
    
    
def boss_fight():
    
    boss_life = 100
    your_life = 100
    
    while boss_life > 0 or your_life > 0: 
        #RPG and Soldier
        if your_weapon == 'RPG' and your_class == 'Soldier':
            boss_life -= weapons_pd.iloc[0,1] * class_pd.iloc[0,1] * randint(51, 120)
            
            
            print(f"\nThe boss has " + str(boss_life) + " health left.\n")
            
            
            if boss_life <= 0:
                print("""
YYYYYYY       YYYYYYY     OOOOOOOOO     UUUUUUUU     UUUUUUUU     WWWWWWWW                           WWWWWWWWIIIIIIIIIINNNNNNNN        NNNNNNNN
Y:::::Y       Y:::::Y   OO:::::::::OO   U::::::U     U::::::U     W::::::W                           W::::::WI::::::::IN:::::::N       N::::::N
Y:::::Y       Y:::::Y OO:::::::::::::OO U::::::U     U::::::U     W::::::W                           W::::::WI::::::::IN::::::::N      N::::::N
Y::::::Y     Y::::::YO:::::::OOO:::::::OUU:::::U     U:::::UU     W::::::W                           W::::::WII::::::IIN:::::::::N     N::::::N
YYY:::::Y   Y:::::YYYO::::::O   O::::::O U:::::U     U:::::U       W:::::W           WWWWW           W:::::W   I::::I  N::::::::::N    N::::::N
   Y:::::Y Y:::::Y   O:::::O     O:::::O U:::::D     D:::::U        W:::::W         W:::::W         W:::::W    I::::I  N:::::::::::N   N::::::N
    Y:::::Y:::::Y    O:::::O     O:::::O U:::::D     D:::::U         W:::::W       W:::::::W       W:::::W     I::::I  N:::::::N::::N  N::::::N
     Y:::::::::Y     O:::::O     O:::::O U:::::D     D:::::U          W:::::W     W:::::::::W     W:::::W      I::::I  N::::::N N::::N N::::::N
      Y:::::::Y      O:::::O     O:::::O U:::::D     D:::::U           W:::::W   W:::::W:::::W   W:::::W       I::::I  N::::::N  N::::N:::::::N
       Y:::::Y       O:::::O     O:::::O U:::::D     D:::::U            W:::::W W:::::W W:::::W W:::::W        I::::I  N::::::N   N:::::::::::N
       Y:::::Y       O:::::O     O:::::O U:::::D     D:::::U             W:::::W:::::W   W:::::W:::::W         I::::I  N::::::N    N::::::::::N
       Y:::::Y       O::::::O   O::::::O U::::::U   U::::::U              W:::::::::W     W:::::::::W          I::::I  N::::::N     N:::::::::N
       Y:::::Y       O:::::::OOO:::::::O U:::::::UUU:::::::U               W:::::::W       W:::::::W         II::::::IIN::::::N      N::::::::N
    YYYY:::::YYYY     OO:::::::::::::OO   UU:::::::::::::UU                 W:::::W         W:::::W          I::::::::IN::::::N       N:::::::N
    Y:::::::::::Y       OO:::::::::OO       UU:::::::::UU                    W:::W           W:::W           I::::::::IN::::::N        N::::::N
    YYYYYYYYYYYYY         OOOOOOOOO           UUUUUUUUU                       WWW             WWW            IIIIIIIIIINNNNNNNN         NNNNNNN               
                """)
                sys.exit(0)
            elif your_life <= 0:
                print("""
You're dead. Do you want to change class or weapon?
1. Class
2. Weapon
                \n""")
                try_again = input('> ')
                if try_again == "1" or try_again == 'Class':
                    choose_class()
                    break
                elif try_again == "2" or try_again == 'Weapon':
                    choose_weapon()
                    break
                elif try_again == '3' or try_again == 'Give up' or try_again == 'Give':
                    fail_1()
                    break
                
            else:
                your_life -= 20
                print(f"\nThe boss also took a swing at you. You have " + str(your_life) + " life left.\n")
                input(' < Press ENTER to take another shot at Olav')
       
        #Mahcine gun and soldier - change text
        elif your_weapon == 'Machine Gun' and your_class == 'Soldier':
            boss_life -= weapons_pd.iloc[1,1] * class_pd.iloc[0,1] * randint(50, 110)
            
            
            print(f"\nThe boss has " + str(boss_life) + " health left.\n")
            
            
            if boss_life <= 0:
                print("""
                
YYYYYYY       YYYYYYY     OOOOOOOOO     UUUUUUUU     UUUUUUUU     WWWWWWWW                           WWWWWWWWIIIIIIIIIINNNNNNNN        NNNNNNNN
Y:::::Y       Y:::::Y   OO:::::::::OO   U::::::U     U::::::U     W::::::W                           W::::::WI::::::::IN:::::::N       N::::::N
Y:::::Y       Y:::::Y OO:::::::::::::OO U::::::U     U::::::U     W::::::W                           W::::::WI::::::::IN::::::::N      N::::::N
Y::::::Y     Y::::::YO:::::::OOO:::::::OUU:::::U     U:::::UU     W::::::W                           W::::::WII::::::IIN:::::::::N     N::::::N
YYY:::::Y   Y:::::YYYO::::::O   O::::::O U:::::U     U:::::U       W:::::W           WWWWW           W:::::W   I::::I  N::::::::::N    N::::::N
   Y:::::Y Y:::::Y   O:::::O     O:::::O U:::::D     D:::::U        W:::::W         W:::::W         W:::::W    I::::I  N:::::::::::N   N::::::N
    Y:::::Y:::::Y    O:::::O     O:::::O U:::::D     D:::::U         W:::::W       W:::::::W       W:::::W     I::::I  N:::::::N::::N  N::::::N
     Y:::::::::Y     O:::::O     O:::::O U:::::D     D:::::U          W:::::W     W:::::::::W     W:::::W      I::::I  N::::::N N::::N N::::::N
      Y:::::::Y      O:::::O     O:::::O U:::::D     D:::::U           W:::::W   W:::::W:::::W   W:::::W       I::::I  N::::::N  N::::N:::::::N
       Y:::::Y       O:::::O     O:::::O U:::::D     D:::::U            W:::::W W:::::W W:::::W W:::::W        I::::I  N::::::N   N:::::::::::N
       Y:::::Y       O:::::O     O:::::O U:::::D     D:::::U             W:::::W:::::W   W:::::W:::::W         I::::I  N::::::N    N::::::::::N
       Y:::::Y       O::::::O   O::::::O U::::::U   U::::::U              W:::::::::W     W:::::::::W          I::::I  N::::::N     N:::::::::N
       Y:::::Y       O:::::::OOO:::::::O U:::::::UUU:::::::U               W:::::::W       W:::::::W         II::::::IIN::::::N      N::::::::N
    YYYY:::::YYYY     OO:::::::::::::OO   UU:::::::::::::UU                 W:::::W         W:::::W          I::::::::IN::::::N       N:::::::N
    Y:::::::::::Y       OO:::::::::OO       UU:::::::::UU                    W:::W           W:::W           I::::::::IN::::::N        N::::::N
    YYYYYYYYYYYYY         OOOOOOOOO           UUUUUUUUU                       WWW             WWW            IIIIIIIIIINNNNNNNN         NNNNNNN                
                
                """)
                sys.exit(0)
                
            elif your_life <= 0:
                print("""
You're dead. Do you want to change class or weapon?
1. Class
2. Weapon
                \n""")
                try_again = input('> ')
                if try_again == "1" or try_again == 'Class':
                    choose_class()
                    break
                elif try_again == "2" or try_again == 'Weapon':
                    choose_weapon()
                    break
                elif try_again == '3' or try_again == 'Give up' or try_again == 'Give':
                    fail_1()
                    break
            else:
                your_life -= 20
                print(f"\nThe boss also took a swing at you. You have " + str(your_life) + " life left.\n")
                input(' < Press ENTER to take another shot at Olav')        
        
        #Pistol and Soldier
        elif your_weapon == 'Pistol' and your_class == 'Soldier':
            
            boss_life -= weapons_pd.iloc[2,1] * class_pd.iloc[0,1] * randint(80, 120)
            
            print(f"\nThe boss has " + str(boss_life) + " health left.\n")
            
            
            if boss_life <= 0:
                print("""
YYYYYYY       YYYYYYY     OOOOOOOOO     UUUUUUUU     UUUUUUUU     WWWWWWWW                           WWWWWWWWIIIIIIIIIINNNNNNNN        NNNNNNNN
Y:::::Y       Y:::::Y   OO:::::::::OO   U::::::U     U::::::U     W::::::W                           W::::::WI::::::::IN:::::::N       N::::::N
Y:::::Y       Y:::::Y OO:::::::::::::OO U::::::U     U::::::U     W::::::W                           W::::::WI::::::::IN::::::::N      N::::::N
Y::::::Y     Y::::::YO:::::::OOO:::::::OUU:::::U     U:::::UU     W::::::W                           W::::::WII::::::IIN:::::::::N     N::::::N
YYY:::::Y   Y:::::YYYO::::::O   O::::::O U:::::U     U:::::U       W:::::W           WWWWW           W:::::W   I::::I  N::::::::::N    N::::::N
   Y:::::Y Y:::::Y   O:::::O     O:::::O U:::::D     D:::::U        W:::::W         W:::::W         W:::::W    I::::I  N:::::::::::N   N::::::N
    Y:::::Y:::::Y    O:::::O     O:::::O U:::::D     D:::::U         W:::::W       W:::::::W       W:::::W     I::::I  N:::::::N::::N  N::::::N
     Y:::::::::Y     O:::::O     O:::::O U:::::D     D:::::U          W:::::W     W:::::::::W     W:::::W      I::::I  N::::::N N::::N N::::::N
      Y:::::::Y      O:::::O     O:::::O U:::::D     D:::::U           W:::::W   W:::::W:::::W   W:::::W       I::::I  N::::::N  N::::N:::::::N
       Y:::::Y       O:::::O     O:::::O U:::::D     D:::::U            W:::::W W:::::W W:::::W W:::::W        I::::I  N::::::N   N:::::::::::N
       Y:::::Y       O:::::O     O:::::O U:::::D     D:::::U             W:::::W:::::W   W:::::W:::::W         I::::I  N::::::N    N::::::::::N
       Y:::::Y       O::::::O   O::::::O U::::::U   U::::::U              W:::::::::W     W:::::::::W          I::::I  N::::::N     N:::::::::N
       Y:::::Y       O:::::::OOO:::::::O U:::::::UUU:::::::U               W:::::::W       W:::::::W         II::::::IIN::::::N      N::::::::N
    YYYY:::::YYYY     OO:::::::::::::OO   UU:::::::::::::UU                 W:::::W         W:::::W          I::::::::IN::::::N       N:::::::N
    Y:::::::::::Y       OO:::::::::OO       UU:::::::::UU                    W:::W           W:::W           I::::::::IN::::::N        N::::::N
    YYYYYYYYYYYYY         OOOOOOOOO           UUUUUUUUU                       WWW             WWW            IIIIIIIIIINNNNNNNN         NNNNNNN                
                """)
                sys.exit(0)
                
            elif your_life <= 0:
                print("""
You're dead. Do you want to change class or weapon?
1. Class
2. Weapon
                \n""")
                try_again = input('> ')
                if try_again == "1" or try_again == 'Class':
                    choose_class()
                    break
                elif try_again == "2" or try_again == 'Weapon':
                    choose_weapon()
                    break
                elif try_again == '3' or try_again == 'Give up' or try_again == 'Give':
                    fail_1()
                    break
            else:
                your_life -= 20
                print(f"\nThe boss also took a swing at you. You have " + str(your_life) + " life left.\n")
                input(' < Press ENTER to take another shot at Olav')
        
        #Bubble gun and Soldier
        elif your_weapon == 'Bubble Gun' and your_class == 'Soldier':
            boss_life -= weapons_pd.iloc[3,1] * class_pd.iloc[0,1] * randint(100, 120)
            
            
            print(f"\nThe boss has " + str(boss_life) + " health left.\n")
            
            
            if boss_life <= 0:
                print("""
YYYYYYY       YYYYYYY     OOOOOOOOO     UUUUUUUU     UUUUUUUU     WWWWWWWW                           WWWWWWWWIIIIIIIIIINNNNNNNN        NNNNNNNN
Y:::::Y       Y:::::Y   OO:::::::::OO   U::::::U     U::::::U     W::::::W                           W::::::WI::::::::IN:::::::N       N::::::N
Y:::::Y       Y:::::Y OO:::::::::::::OO U::::::U     U::::::U     W::::::W                           W::::::WI::::::::IN::::::::N      N::::::N
Y::::::Y     Y::::::YO:::::::OOO:::::::OUU:::::U     U:::::UU     W::::::W                           W::::::WII::::::IIN:::::::::N     N::::::N
YYY:::::Y   Y:::::YYYO::::::O   O::::::O U:::::U     U:::::U       W:::::W           WWWWW           W:::::W   I::::I  N::::::::::N    N::::::N
   Y:::::Y Y:::::Y   O:::::O     O:::::O U:::::D     D:::::U        W:::::W         W:::::W         W:::::W    I::::I  N:::::::::::N   N::::::N
    Y:::::Y:::::Y    O:::::O     O:::::O U:::::D     D:::::U         W:::::W       W:::::::W       W:::::W     I::::I  N:::::::N::::N  N::::::N
     Y:::::::::Y     O:::::O     O:::::O U:::::D     D:::::U          W:::::W     W:::::::::W     W:::::W      I::::I  N::::::N N::::N N::::::N
      Y:::::::Y      O:::::O     O:::::O U:::::D     D:::::U           W:::::W   W:::::W:::::W   W:::::W       I::::I  N::::::N  N::::N:::::::N
       Y:::::Y       O:::::O     O:::::O U:::::D     D:::::U            W:::::W W:::::W W:::::W W:::::W        I::::I  N::::::N   N:::::::::::N
       Y:::::Y       O:::::O     O:::::O U:::::D     D:::::U             W:::::W:::::W   W:::::W:::::W         I::::I  N::::::N    N::::::::::N
       Y:::::Y       O::::::O   O::::::O U::::::U   U::::::U              W:::::::::W     W:::::::::W          I::::I  N::::::N     N:::::::::N
       Y:::::Y       O:::::::OOO:::::::O U:::::::UUU:::::::U               W:::::::W       W:::::::W         II::::::IIN::::::N      N::::::::N
    YYYY:::::YYYY     OO:::::::::::::OO   UU:::::::::::::UU                 W:::::W         W:::::W          I::::::::IN::::::N       N:::::::N
    Y:::::::::::Y       OO:::::::::OO       UU:::::::::UU                    W:::W           W:::W           I::::::::IN::::::N        N::::::N
    YYYYYYYYYYYYY         OOOOOOOOO           UUUUUUUUU                       WWW             WWW            IIIIIIIIIINNNNNNNN         NNNNNNN                
                """)
                sys.exit(0)
            
            elif your_life <= 0:
                print("""
You're dead. Do you want to change class or weapon?
1. Class
2. Weapon
                \n""")
                try_again = input('> ')
                if try_again == "1" or try_again == 'Class':
                    choose_class()
                    break
                elif try_again == "2" or try_again == 'Weapon':
                    choose_weapon()
                    break 
                elif try_again == '3' or try_again == 'Give up' or try_again == 'Give':
                    fail_1()
                    break
            
            else:
                your_life -= 20
                print(f"\nThe boss also took a swing at you. You have " + str(your_life) + " life left.\n")
                input(' < Press ENTER to take another shot at Olav')
        
        #RPG and Siren
        elif your_weapon == 'RPG' and your_class == 'Siren':
            boss_life -= weapons_pd.iloc[0,1] * class_pd.iloc[1,1] * randint(80, 120)
            
            
            print(f"\nThe boss has " + str(boss_life) + " health left.\n")
            
            
            if boss_life <= 0:
                print("""
YYYYYYY       YYYYYYY     OOOOOOOOO     UUUUUUUU     UUUUUUUU     WWWWWWWW                           WWWWWWWWIIIIIIIIIINNNNNNNN        NNNNNNNN
Y:::::Y       Y:::::Y   OO:::::::::OO   U::::::U     U::::::U     W::::::W                           W::::::WI::::::::IN:::::::N       N::::::N
Y:::::Y       Y:::::Y OO:::::::::::::OO U::::::U     U::::::U     W::::::W                           W::::::WI::::::::IN::::::::N      N::::::N
Y::::::Y     Y::::::YO:::::::OOO:::::::OUU:::::U     U:::::UU     W::::::W                           W::::::WII::::::IIN:::::::::N     N::::::N
YYY:::::Y   Y:::::YYYO::::::O   O::::::O U:::::U     U:::::U       W:::::W           WWWWW           W:::::W   I::::I  N::::::::::N    N::::::N
   Y:::::Y Y:::::Y   O:::::O     O:::::O U:::::D     D:::::U        W:::::W         W:::::W         W:::::W    I::::I  N:::::::::::N   N::::::N
    Y:::::Y:::::Y    O:::::O     O:::::O U:::::D     D:::::U         W:::::W       W:::::::W       W:::::W     I::::I  N:::::::N::::N  N::::::N
     Y:::::::::Y     O:::::O     O:::::O U:::::D     D:::::U          W:::::W     W:::::::::W     W:::::W      I::::I  N::::::N N::::N N::::::N
      Y:::::::Y      O:::::O     O:::::O U:::::D     D:::::U           W:::::W   W:::::W:::::W   W:::::W       I::::I  N::::::N  N::::N:::::::N
       Y:::::Y       O:::::O     O:::::O U:::::D     D:::::U            W:::::W W:::::W W:::::W W:::::W        I::::I  N::::::N   N:::::::::::N
       Y:::::Y       O:::::O     O:::::O U:::::D     D:::::U             W:::::W:::::W   W:::::W:::::W         I::::I  N::::::N    N::::::::::N
       Y:::::Y       O::::::O   O::::::O U::::::U   U::::::U              W:::::::::W     W:::::::::W          I::::I  N::::::N     N:::::::::N
       Y:::::Y       O:::::::OOO:::::::O U:::::::UUU:::::::U               W:::::::W       W:::::::W         II::::::IIN::::::N      N::::::::N
    YYYY:::::YYYY     OO:::::::::::::OO   UU:::::::::::::UU                 W:::::W         W:::::W          I::::::::IN::::::N       N:::::::N
    Y:::::::::::Y       OO:::::::::OO       UU:::::::::UU                    W:::W           W:::W           I::::::::IN::::::N        N::::::N
    YYYYYYYYYYYYY         OOOOOOOOO           UUUUUUUUU                       WWW             WWW            IIIIIIIIIINNNNNNNN         NNNNNNN                
                """)
                sys.exit(0)
            
            elif your_life <= 0:
                print("""
You're dead. Do you want to change class or weapon?
1. Class
2. Weapon
                \n""")
                try_again = input('> ')
                if try_again == "1" or try_again == 'Class':
                    choose_class()
                    break
                elif try_again == "2" or try_again == 'Weapon':
                    choose_weapon()
                    break  
                elif try_again == '3' or try_again == 'Give up' or try_again == 'Give':
                    fail_1()
                    break
            
            else:
                your_life -= 20
                print(f"\nThe boss also took a swing at you. You have " + str(your_life) + " life left.\n")
                input(' < Press ENTER to take another shot at Olav')
        
        #Machine Gun and Siren        
        elif your_weapon == 'Machine Gun' and your_class == 'Siren':
            boss_life -= weapons_pd.iloc[1,1] * class_pd.iloc[1,1] * randint(80, 120)
            
            
            print(f"\nThe boss has " + str(boss_life) + " health left.\n")
            
            
            if boss_life <= 0:
                print("""
YYYYYYY       YYYYYYY     OOOOOOOOO     UUUUUUUU     UUUUUUUU     WWWWWWWW                           WWWWWWWWIIIIIIIIIINNNNNNNN        NNNNNNNN
Y:::::Y       Y:::::Y   OO:::::::::OO   U::::::U     U::::::U     W::::::W                           W::::::WI::::::::IN:::::::N       N::::::N
Y:::::Y       Y:::::Y OO:::::::::::::OO U::::::U     U::::::U     W::::::W                           W::::::WI::::::::IN::::::::N      N::::::N
Y::::::Y     Y::::::YO:::::::OOO:::::::OUU:::::U     U:::::UU     W::::::W                           W::::::WII::::::IIN:::::::::N     N::::::N
YYY:::::Y   Y:::::YYYO::::::O   O::::::O U:::::U     U:::::U       W:::::W           WWWWW           W:::::W   I::::I  N::::::::::N    N::::::N
   Y:::::Y Y:::::Y   O:::::O     O:::::O U:::::D     D:::::U        W:::::W         W:::::W         W:::::W    I::::I  N:::::::::::N   N::::::N
    Y:::::Y:::::Y    O:::::O     O:::::O U:::::D     D:::::U         W:::::W       W:::::::W       W:::::W     I::::I  N:::::::N::::N  N::::::N
     Y:::::::::Y     O:::::O     O:::::O U:::::D     D:::::U          W:::::W     W:::::::::W     W:::::W      I::::I  N::::::N N::::N N::::::N
      Y:::::::Y      O:::::O     O:::::O U:::::D     D:::::U           W:::::W   W:::::W:::::W   W:::::W       I::::I  N::::::N  N::::N:::::::N
       Y:::::Y       O:::::O     O:::::O U:::::D     D:::::U            W:::::W W:::::W W:::::W W:::::W        I::::I  N::::::N   N:::::::::::N
       Y:::::Y       O:::::O     O:::::O U:::::D     D:::::U             W:::::W:::::W   W:::::W:::::W         I::::I  N::::::N    N::::::::::N
       Y:::::Y       O::::::O   O::::::O U::::::U   U::::::U              W:::::::::W     W:::::::::W          I::::I  N::::::N     N:::::::::N
       Y:::::Y       O:::::::OOO:::::::O U:::::::UUU:::::::U               W:::::::W       W:::::::W         II::::::IIN::::::N      N::::::::N
    YYYY:::::YYYY     OO:::::::::::::OO   UU:::::::::::::UU                 W:::::W         W:::::W          I::::::::IN::::::N       N:::::::N
    Y:::::::::::Y       OO:::::::::OO       UU:::::::::UU                    W:::W           W:::W           I::::::::IN::::::N        N::::::N
    YYYYYYYYYYYYY         OOOOOOOOO           UUUUUUUUU                       WWW             WWW            IIIIIIIIIINNNNNNNN         NNNNNNN                
                
                """)
                sys.exit(0)
            
            elif your_life <= 0:
                print("""
You're dead. Do you want to change class or weapon?
1. Class
2. Weapon
                \n""")
                try_again = input('> ')
                if try_again == "1" or try_again == 'Class':
                    choose_class()
                    break
                elif try_again == "2" or try_again == 'Weapon':
                    choose_weapon()
                    break
                elif try_again == '3' or try_again == 'Give up' or try_again == 'Give':
                    fail_1()
                    break
                
            else:
                your_life -= 20
                print(f"\nThe boss also took a swing at you. You have " + str(your_life) + " life left.\n")
                input(' < Press ENTER to take another shot at Olav')
        
        #Pistol and Siren        
        elif your_weapon == 'Pistol' and your_class == 'Siren':
            boss_life -= weapons_pd.iloc[2,1] * class_pd.iloc[1,1] * randint(100, 120)
            
            
            print(f"\nThe boss has " + str(boss_life) + " health left.\n")
            
            
            if boss_life <= 0:
                print("""
YYYYYYY       YYYYYYY     OOOOOOOOO     UUUUUUUU     UUUUUUUU     WWWWWWWW                           WWWWWWWWIIIIIIIIIINNNNNNNN        NNNNNNNN
Y:::::Y       Y:::::Y   OO:::::::::OO   U::::::U     U::::::U     W::::::W                           W::::::WI::::::::IN:::::::N       N::::::N
Y:::::Y       Y:::::Y OO:::::::::::::OO U::::::U     U::::::U     W::::::W                           W::::::WI::::::::IN::::::::N      N::::::N
Y::::::Y     Y::::::YO:::::::OOO:::::::OUU:::::U     U:::::UU     W::::::W                           W::::::WII::::::IIN:::::::::N     N::::::N
YYY:::::Y   Y:::::YYYO::::::O   O::::::O U:::::U     U:::::U       W:::::W           WWWWW           W:::::W   I::::I  N::::::::::N    N::::::N
   Y:::::Y Y:::::Y   O:::::O     O:::::O U:::::D     D:::::U        W:::::W         W:::::W         W:::::W    I::::I  N:::::::::::N   N::::::N
    Y:::::Y:::::Y    O:::::O     O:::::O U:::::D     D:::::U         W:::::W       W:::::::W       W:::::W     I::::I  N:::::::N::::N  N::::::N
     Y:::::::::Y     O:::::O     O:::::O U:::::D     D:::::U          W:::::W     W:::::::::W     W:::::W      I::::I  N::::::N N::::N N::::::N
      Y:::::::Y      O:::::O     O:::::O U:::::D     D:::::U           W:::::W   W:::::W:::::W   W:::::W       I::::I  N::::::N  N::::N:::::::N
       Y:::::Y       O:::::O     O:::::O U:::::D     D:::::U            W:::::W W:::::W W:::::W W:::::W        I::::I  N::::::N   N:::::::::::N
       Y:::::Y       O:::::O     O:::::O U:::::D     D:::::U             W:::::W:::::W   W:::::W:::::W         I::::I  N::::::N    N::::::::::N
       Y:::::Y       O::::::O   O::::::O U::::::U   U::::::U              W:::::::::W     W:::::::::W          I::::I  N::::::N     N:::::::::N
       Y:::::Y       O:::::::OOO:::::::O U:::::::UUU:::::::U               W:::::::W       W:::::::W         II::::::IIN::::::N      N::::::::N
    YYYY:::::YYYY     OO:::::::::::::OO   UU:::::::::::::UU                 W:::::W         W:::::W          I::::::::IN::::::N       N:::::::N
    Y:::::::::::Y       OO:::::::::OO       UU:::::::::UU                    W:::W           W:::W           I::::::::IN::::::N        N::::::N
    YYYYYYYYYYYYY         OOOOOOOOO           UUUUUUUUU                       WWW             WWW            IIIIIIIIIINNNNNNNN         NNNNNNN                
                """)
                sys.exit(0)
            
            elif your_life <= 0:
                print("""
You're dead. Do you want to change class or weapon?
1. Class
2. Weapon
                \n""")
                try_again = input('> ')
                if try_again == "1" or try_again == 'Class':
                    choose_class()
                    break
                elif try_again == "2" or try_again == 'Weapon':
                    choose_weapon()
                    break 
                elif try_again == '3' or try_again == 'Give up' or try_again == 'Give':
                    fail_1()
                    break
            
            else:
                your_life -= 20
                print(f"\nThe boss also took a swing at you. You have " + str(your_life) + " life left.\n")
                input(' < Press ENTER to take another shot at Olav')
        #Bubble gun and Siren        
        elif your_weapon == 'Bubble Gun' and your_class == 'Siren':
            boss_life -= weapons_pd.iloc[3,1] * class_pd.iloc[1,1] * randint(80, 120)
            
            
            print(f"\nThe boss has " + str(boss_life) + " health left.\n")
            
            
            if boss_life <= 0:
                print("""
                
YYYYYYY       YYYYYYY     OOOOOOOOO     UUUUUUUU     UUUUUUUU     WWWWWWWW                           WWWWWWWWIIIIIIIIIINNNNNNNN        NNNNNNNN
Y:::::Y       Y:::::Y   OO:::::::::OO   U::::::U     U::::::U     W::::::W                           W::::::WI::::::::IN:::::::N       N::::::N
Y:::::Y       Y:::::Y OO:::::::::::::OO U::::::U     U::::::U     W::::::W                           W::::::WI::::::::IN::::::::N      N::::::N
Y::::::Y     Y::::::YO:::::::OOO:::::::OUU:::::U     U:::::UU     W::::::W                           W::::::WII::::::IIN:::::::::N     N::::::N
YYY:::::Y   Y:::::YYYO::::::O   O::::::O U:::::U     U:::::U       W:::::W           WWWWW           W:::::W   I::::I  N::::::::::N    N::::::N
   Y:::::Y Y:::::Y   O:::::O     O:::::O U:::::D     D:::::U        W:::::W         W:::::W         W:::::W    I::::I  N:::::::::::N   N::::::N
    Y:::::Y:::::Y    O:::::O     O:::::O U:::::D     D:::::U         W:::::W       W:::::::W       W:::::W     I::::I  N:::::::N::::N  N::::::N
     Y:::::::::Y     O:::::O     O:::::O U:::::D     D:::::U          W:::::W     W:::::::::W     W:::::W      I::::I  N::::::N N::::N N::::::N
      Y:::::::Y      O:::::O     O:::::O U:::::D     D:::::U           W:::::W   W:::::W:::::W   W:::::W       I::::I  N::::::N  N::::N:::::::N
       Y:::::Y       O:::::O     O:::::O U:::::D     D:::::U            W:::::W W:::::W W:::::W W:::::W        I::::I  N::::::N   N:::::::::::N
       Y:::::Y       O:::::O     O:::::O U:::::D     D:::::U             W:::::W:::::W   W:::::W:::::W         I::::I  N::::::N    N::::::::::N
       Y:::::Y       O::::::O   O::::::O U::::::U   U::::::U              W:::::::::W     W:::::::::W          I::::I  N::::::N     N:::::::::N
       Y:::::Y       O:::::::OOO:::::::O U:::::::UUU:::::::U               W:::::::W       W:::::::W         II::::::IIN::::::N      N::::::::N
    YYYY:::::YYYY     OO:::::::::::::OO   UU:::::::::::::UU                 W:::::W         W:::::W          I::::::::IN::::::N       N:::::::N
    Y:::::::::::Y       OO:::::::::OO       UU:::::::::UU                    W:::W           W:::W           I::::::::IN::::::N        N::::::N
    YYYYYYYYYYYYY         OOOOOOOOO           UUUUUUUUU                       WWW             WWW            IIIIIIIIIINNNNNNNN         NNNNNNN                
                
                """)
                sys.exit(0)
                
            elif your_life <= 0:
                print("""
You're dead. Do you want to change class or weapon?
1. Class
2. Weapon
                \n""")
                try_again = input('> ')
                if try_again == "1" or try_again == 'Class':
                    choose_class()
                    break
                elif try_again == "2" or try_again == 'Weapon':
                    choose_weapon()
                    break 
                elif try_again == '3' or try_again == 'Give up' or try_again == 'Give':
                    fail_1()
                    break
            
            else:
                your_life -= 20
                print(f"\nThe boss also took a swing at you. You have " + str(your_life) + " life left.\n")
                input(' < Press ENTER to take another shot at Olav')
                
        #RPG and hunter
        elif your_weapon == 'RPG' and your_class == 'Hunter':
            boss_life -= weapons_pd.iloc[0,1] * class_pd.iloc[2,1] * randint(80, 120)
            
            
            print(f"\nThe boss has " + str(boss_life) + " health left.\n")
            
            
            if boss_life <= 0:
                print("""
                
YYYYYYY       YYYYYYY     OOOOOOOOO     UUUUUUUU     UUUUUUUU     WWWWWWWW                           WWWWWWWWIIIIIIIIIINNNNNNNN        NNNNNNNN
Y:::::Y       Y:::::Y   OO:::::::::OO   U::::::U     U::::::U     W::::::W                           W::::::WI::::::::IN:::::::N       N::::::N
Y:::::Y       Y:::::Y OO:::::::::::::OO U::::::U     U::::::U     W::::::W                           W::::::WI::::::::IN::::::::N      N::::::N
Y::::::Y     Y::::::YO:::::::OOO:::::::OUU:::::U     U:::::UU     W::::::W                           W::::::WII::::::IIN:::::::::N     N::::::N
YYY:::::Y   Y:::::YYYO::::::O   O::::::O U:::::U     U:::::U       W:::::W           WWWWW           W:::::W   I::::I  N::::::::::N    N::::::N
   Y:::::Y Y:::::Y   O:::::O     O:::::O U:::::D     D:::::U        W:::::W         W:::::W         W:::::W    I::::I  N:::::::::::N   N::::::N
    Y:::::Y:::::Y    O:::::O     O:::::O U:::::D     D:::::U         W:::::W       W:::::::W       W:::::W     I::::I  N:::::::N::::N  N::::::N
     Y:::::::::Y     O:::::O     O:::::O U:::::D     D:::::U          W:::::W     W:::::::::W     W:::::W      I::::I  N::::::N N::::N N::::::N
      Y:::::::Y      O:::::O     O:::::O U:::::D     D:::::U           W:::::W   W:::::W:::::W   W:::::W       I::::I  N::::::N  N::::N:::::::N
       Y:::::Y       O:::::O     O:::::O U:::::D     D:::::U            W:::::W W:::::W W:::::W W:::::W        I::::I  N::::::N   N:::::::::::N
       Y:::::Y       O:::::O     O:::::O U:::::D     D:::::U             W:::::W:::::W   W:::::W:::::W         I::::I  N::::::N    N::::::::::N
       Y:::::Y       O::::::O   O::::::O U::::::U   U::::::U              W:::::::::W     W:::::::::W          I::::I  N::::::N     N:::::::::N
       Y:::::Y       O:::::::OOO:::::::O U:::::::UUU:::::::U               W:::::::W       W:::::::W         II::::::IIN::::::N      N::::::::N
    YYYY:::::YYYY     OO:::::::::::::OO   UU:::::::::::::UU                 W:::::W         W:::::W          I::::::::IN::::::N       N:::::::N
    Y:::::::::::Y       OO:::::::::OO       UU:::::::::UU                    W:::W           W:::W           I::::::::IN::::::N        N::::::N
    YYYYYYYYYYYYY         OOOOOOOOO           UUUUUUUUU                       WWW             WWW            IIIIIIIIIINNNNNNNN         NNNNNNN                
                """)
                sys.exit(0)
                
            elif your_life <= 0:
                print("""
You're dead. Do you want to change class or weapon?
1. Class
2. Weapon
                \n""")
                try_again = input('> ')
                if try_again == "1" or try_again == 'Class':
                    choose_class()
                    break
                elif try_again == "2" or try_again == 'Weapon':
                    choose_weapon()
                    break
                elif try_again == '3' or try_again == 'Give up' or try_again == 'Give':
                    fail_1()
                    break
                    
            else:
                your_life -= 20
                print(f"\nThe boss also took a swing at you. You have " + str(your_life) + " life left.\n")
                input(' < Press ENTER to take another shot at Olav')
        
        #Machine Gun and hunter - fix randint / dmg and ifs
        elif your_weapon =='Machine Gun' and your_class =='Hunter':
            boss_life -= weapons_pd.iloc[1,1] * class_pd.iloc[2,1] * randint(51, 120)

            
            print(f"\nThe boss has " + str(boss_life) + " health left.\n")
        
            
            if boss_life <= 0:
                print("""
                
YYYYYYY       YYYYYYY     OOOOOOOOO     UUUUUUUU     UUUUUUUU     WWWWWWWW                           WWWWWWWWIIIIIIIIIINNNNNNNN        NNNNNNNN
Y:::::Y       Y:::::Y   OO:::::::::OO   U::::::U     U::::::U     W::::::W                           W::::::WI::::::::IN:::::::N       N::::::N
Y:::::Y       Y:::::Y OO:::::::::::::OO U::::::U     U::::::U     W::::::W                           W::::::WI::::::::IN::::::::N      N::::::N
Y::::::Y     Y::::::YO:::::::OOO:::::::OUU:::::U     U:::::UU     W::::::W                           W::::::WII::::::IIN:::::::::N     N::::::N
YYY:::::Y   Y:::::YYYO::::::O   O::::::O U:::::U     U:::::U       W:::::W           WWWWW           W:::::W   I::::I  N::::::::::N    N::::::N
   Y:::::Y Y:::::Y   O:::::O     O:::::O U:::::D     D:::::U        W:::::W         W:::::W         W:::::W    I::::I  N:::::::::::N   N::::::N
    Y:::::Y:::::Y    O:::::O     O:::::O U:::::D     D:::::U         W:::::W       W:::::::W       W:::::W     I::::I  N:::::::N::::N  N::::::N
     Y:::::::::Y     O:::::O     O:::::O U:::::D     D:::::U          W:::::W     W:::::::::W     W:::::W      I::::I  N::::::N N::::N N::::::N
      Y:::::::Y      O:::::O     O:::::O U:::::D     D:::::U           W:::::W   W:::::W:::::W   W:::::W       I::::I  N::::::N  N::::N:::::::N
       Y:::::Y       O:::::O     O:::::O U:::::D     D:::::U            W:::::W W:::::W W:::::W W:::::W        I::::I  N::::::N   N:::::::::::N
       Y:::::Y       O:::::O     O:::::O U:::::D     D:::::U             W:::::W:::::W   W:::::W:::::W         I::::I  N::::::N    N::::::::::N
       Y:::::Y       O::::::O   O::::::O U::::::U   U::::::U              W:::::::::W     W:::::::::W          I::::I  N::::::N     N:::::::::N
       Y:::::Y       O:::::::OOO:::::::O U:::::::UUU:::::::U               W:::::::W       W:::::::W         II::::::IIN::::::N      N::::::::N
    YYYY:::::YYYY     OO:::::::::::::OO   UU:::::::::::::UU                 W:::::W         W:::::W          I::::::::IN::::::N       N:::::::N
    Y:::::::::::Y       OO:::::::::OO       UU:::::::::UU                    W:::W           W:::W           I::::::::IN::::::N        N::::::N
    YYYYYYYYYYYYY         OOOOOOOOO           UUUUUUUUU                       WWW             WWW            IIIIIIIIIINNNNNNNN         NNNNNNN                
                
                """)
                sys.exit(0)
                
            elif your_life <= 0:
                print("""
You're dead. Do you want to change class or weapon?
1. Class
2. Weapon
                \n""")
                try_again = input('> ')
                if try_again == "1" or try_again == 'Class':
                    choose_class()
                    break
                elif try_again == "2" or try_again == 'Weapon':
                    choose_weapon()
                    break
                elif try_again == '3' or try_again == 'Give up' or try_again == 'Give':
                    fail_1()
                    break
                
            
            else:
                your_life -= 20
                print(f"\nThe boss also took a swing at you. You have " + str(your_life) + " life left.\n")
                input(' < Press ENTER to take another shot at Olav')
                
        #Pistole gun and Hunter
        elif your_weapon =='Pistol' and your_class == 'Hunter':
            boss_life -= weapons_pd.iloc[2,1] * class_pd.iloc[2,1] * randint(51, 120)
            
            
            print(f"\nThe boss has " + str(boss_life) + " health left.\n")
            
            
            if boss_life <= 0:
                print("""
                
YYYYYYY       YYYYYYY     OOOOOOOOO     UUUUUUUU     UUUUUUUU     WWWWWWWW                           WWWWWWWWIIIIIIIIIINNNNNNNN        NNNNNNNN
Y:::::Y       Y:::::Y   OO:::::::::OO   U::::::U     U::::::U     W::::::W                           W::::::WI::::::::IN:::::::N       N::::::N
Y:::::Y       Y:::::Y OO:::::::::::::OO U::::::U     U::::::U     W::::::W                           W::::::WI::::::::IN::::::::N      N::::::N
Y::::::Y     Y::::::YO:::::::OOO:::::::OUU:::::U     U:::::UU     W::::::W                           W::::::WII::::::IIN:::::::::N     N::::::N
YYY:::::Y   Y:::::YYYO::::::O   O::::::O U:::::U     U:::::U       W:::::W           WWWWW           W:::::W   I::::I  N::::::::::N    N::::::N
   Y:::::Y Y:::::Y   O:::::O     O:::::O U:::::D     D:::::U        W:::::W         W:::::W         W:::::W    I::::I  N:::::::::::N   N::::::N
    Y:::::Y:::::Y    O:::::O     O:::::O U:::::D     D:::::U         W:::::W       W:::::::W       W:::::W     I::::I  N:::::::N::::N  N::::::N
     Y:::::::::Y     O:::::O     O:::::O U:::::D     D:::::U          W:::::W     W:::::::::W     W:::::W      I::::I  N::::::N N::::N N::::::N
      Y:::::::Y      O:::::O     O:::::O U:::::D     D:::::U           W:::::W   W:::::W:::::W   W:::::W       I::::I  N::::::N  N::::N:::::::N
       Y:::::Y       O:::::O     O:::::O U:::::D     D:::::U            W:::::W W:::::W W:::::W W:::::W        I::::I  N::::::N   N:::::::::::N
       Y:::::Y       O:::::O     O:::::O U:::::D     D:::::U             W:::::W:::::W   W:::::W:::::W         I::::I  N::::::N    N::::::::::N
       Y:::::Y       O::::::O   O::::::O U::::::U   U::::::U              W:::::::::W     W:::::::::W          I::::I  N::::::N     N:::::::::N
       Y:::::Y       O:::::::OOO:::::::O U:::::::UUU:::::::U               W:::::::W       W:::::::W         II::::::IIN::::::N      N::::::::N
    YYYY:::::YYYY     OO:::::::::::::OO   UU:::::::::::::UU                 W:::::W         W:::::W          I::::::::IN::::::N       N:::::::N
    Y:::::::::::Y       OO:::::::::OO       UU:::::::::UU                    W:::W           W:::W           I::::::::IN::::::N        N::::::N
    YYYYYYYYYYYYY         OOOOOOOOO           UUUUUUUUU                       WWW             WWW            IIIIIIIIIINNNNNNNN         NNNNNNN                
                
                
                
                
                """)
                sys.exit(0)
                
            elif your_life <= 0:
                print("""
You're dead. Do you want to change class or weapon?
1. Class
2. Weapon
                \n""")
                try_again = input('> ')
                if try_again == "1" or try_again == 'Class':
                    choose_class()
                    break
                elif try_again == "2" or try_again == 'Weapon':
                    choose_weapon()
                    break
                elif try_again == '3' or try_again == 'Give up' or try_again == 'Give':
                    fail_1()
                    break
            else:
                your_life -= 20
                print(f"\nThe boss also took a swing at you. You have " + str(your_life) + " life left.\n")
                input(' < Press ENTER to take another shot at Olav')
                
        elif your_weapon =='Bubble gun' and your_class == 'Hunter':
            boss_life -= weapons_pd.iloc[3,1] * class_pd.iloc[2,1] * randint(51, 120)
            
            
            print(f"\nThe boss has " + str(boss_life) + " health left.\n")
            
            
            if boss_life <= 0:
                print("""

YYYYYYY       YYYYYYY     OOOOOOOOO     UUUUUUUU     UUUUUUUU     WWWWWWWW                           WWWWWWWWIIIIIIIIIINNNNNNNN        NNNNNNNN
Y:::::Y       Y:::::Y   OO:::::::::OO   U::::::U     U::::::U     W::::::W                           W::::::WI::::::::IN:::::::N       N::::::N
Y:::::Y       Y:::::Y OO:::::::::::::OO U::::::U     U::::::U     W::::::W                           W::::::WI::::::::IN::::::::N      N::::::N
Y::::::Y     Y::::::YO:::::::OOO:::::::OUU:::::U     U:::::UU     W::::::W                           W::::::WII::::::IIN:::::::::N     N::::::N
YYY:::::Y   Y:::::YYYO::::::O   O::::::O U:::::U     U:::::U       W:::::W           WWWWW           W:::::W   I::::I  N::::::::::N    N::::::N
   Y:::::Y Y:::::Y   O:::::O     O:::::O U:::::D     D:::::U        W:::::W         W:::::W         W:::::W    I::::I  N:::::::::::N   N::::::N
    Y:::::Y:::::Y    O:::::O     O:::::O U:::::D     D:::::U         W:::::W       W:::::::W       W:::::W     I::::I  N:::::::N::::N  N::::::N
     Y:::::::::Y     O:::::O     O:::::O U:::::D     D:::::U          W:::::W     W:::::::::W     W:::::W      I::::I  N::::::N N::::N N::::::N
      Y:::::::Y      O:::::O     O:::::O U:::::D     D:::::U           W:::::W   W:::::W:::::W   W:::::W       I::::I  N::::::N  N::::N:::::::N
       Y:::::Y       O:::::O     O:::::O U:::::D     D:::::U            W:::::W W:::::W W:::::W W:::::W        I::::I  N::::::N   N:::::::::::N
       Y:::::Y       O:::::O     O:::::O U:::::D     D:::::U             W:::::W:::::W   W:::::W:::::W         I::::I  N::::::N    N::::::::::N
       Y:::::Y       O::::::O   O::::::O U::::::U   U::::::U              W:::::::::W     W:::::::::W          I::::I  N::::::N     N:::::::::N
       Y:::::Y       O:::::::OOO:::::::O U:::::::UUU:::::::U               W:::::::W       W:::::::W         II::::::IIN::::::N      N::::::::N
    YYYY:::::YYYY     OO:::::::::::::OO   UU:::::::::::::UU                 W:::::W         W:::::W          I::::::::IN::::::N       N:::::::N
    Y:::::::::::Y       OO:::::::::OO       UU:::::::::UU                    W:::W           W:::W           I::::::::IN::::::N        N::::::N
    YYYYYYYYYYYYY         OOOOOOOOO           UUUUUUUUU                       WWW             WWW            IIIIIIIIIINNNNNNNN         NNNNNNN
                
                
                """)
                exit(0)
                
            elif your_life <= 0:
                print("""
You're dead. Do you want to change class or weapon?
1. Class
2. Weapon
3. I give up.
                \n""")
                try_again = input('> ')
                if try_again == "1" or try_again == 'Class':
                    choose_class()
                    break
                elif try_again == "2" or try_again == 'Weapon':
                    choose_weapon()
                    break
                elif try_again == '3' or try_again == 'Give up' or try_again == 'Give':
                    fail_1()
                    break
                    
            else:
                your_life -= 20
                print(f"\nThe boss also took a swing at you. You have " + str(your_life) + " life left.\n")
                input(' < Press ENTER to take another shot at Olav')
        
        else:
            print("Well what happens now..?")
            break

    
               
        
def fail_1():
    print(f"""\n\n
Alright {your_name}, I don't think this bloodshed-of-a-journey is something for you. \n\n
    Since I am a nice Captain I will give you one more chance. Would you like to go back to class selection? (Yes/No)
    """)
    
    class_select = input('> ')
    class_select = class_select.lower()
    
    if class_select == 'yes' or class_select == 'y':
        choose_class()
    else:
        print(f"""
Well, alright {your_name}. Since you are being such a coward, I will not let you go before I have told you a story about my raindeer.
You might ask yourself how a specialised and SUPER-INTELLIGENT robot like me can own a raindeer, so it is a shame that you will never know the answer to this.
This is basically because you and I don't share the same murderous adventureness. 
With that being said, his name is Rudolf. He is the best snugler in the world, he love belly-scratches and has a sweetspot at his left ribcage.
He is originally from the North Pole. Rudolf's previous owner wasn't that nice to him, he was only used for pulling a sled.
Did I mention that Rudolf can fly? He pulled the sled through the atmosphere, but he didn't really enjoy it. 
That is why I killed his last owner, a big fat man with a massive beard. He appeared nice, but I had to free my dear Rudolf.
Hope you enjoyed my story. Now get out of my face. You have really wasted my time. 
Good bye, stranger. 
        """)
        sys.exit(0)
        

        
            
        
############
#GAME START#
############
    
game_start()
# Out:
# Hello! You must be the new recruit. Welcome to Pandora, the land of murderers and thieves. My name is Claptrap, and I am the General of the Crimson Raiders!
#
# So, Recruit, what is your first name?
#
# > Becky
# Alright Becky. What is your last name? Just for... You know... Eh. Nevermind.
#
# > Kim
#
# Thank you very much, Becky Kim. I will preorder your tombstone juuuuuuuuuuuuuust in case, but don't worry...
#
#
# yet.
#
#
# Remember that every choice you make from this point on will determine your future... (if you will even have one.)
#
# Before continuing our journey you need to pick your desired class.< Press Enter to Continue >
#
# So, Recruit Kim, what class do you choose?
#         1. The ULTIMATE Soldier.
#         2. The Magical Siren.
#         3. The UnderDOG Hunter.
# Choose your class: 1
#
# Good for you. You have upgraded to Apprentice Soldier Kim.
# < Press Enter to Continue your journey! >
#
# Now follow me to this super-secret weaponlocker.
# ...
